# %% [markdown]
# # SQL SORGULARI ARACILIĞIYLA VERITABANINA ERIŞMEK IÇIN PYTHON KULLANMAK

# %% [markdown]
# ### ipython-sql'i yükleyin

# %%
! pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Collecting prettytable
#   Downloading prettytable-3.6.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: six in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython-sql) (1.15.0)
# Requirement already satisfied: ipython-genutils in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython-sql) (0.2.0)
# Collecting sqlparse
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 605.4 kB/s eta 0:00:00 0:00:01
# Collecting sqlalchemy>=2.0
#   Downloading SQLAlchemy-2.0.8-cp39-cp39-macosx_10_9_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 2.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: ipython in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython-sql) (7.31.1)
# Collecting typing-extensions>=4.2.0
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from sqlalchemy>=2.0->ipython-sql) (1.1.1)
# Requirement already satisfied: backcall in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: pickleshare in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (63.4.1)
# Requirement already satisfied: traitlets>=4.2 in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (3.0.20)
# Requirement already satisfied: appnope in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (0.1.2)
# Requirement already satisfied: matplotlib-inline in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: jedi>=0.16 in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: pygments in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (2.11.2)
# Requirement already satisfied: decorator in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: wcwidth in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/imac/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Installing collected packages: typing-extensions, sqlparse, prettytable, sqlalchemy, ipython-sql
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.39
#     Uninstalling SQLAlchemy-1.4.39:
#       Successfully uninstalled SQLAlchemy-1.4.39
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.6.5 requires typing-extensions<3.11,>=3.7, but you have typing-extensions 4.5.0 which is incompatible.
# Successfully installed ipython-sql-0.5.0 prettytable-3.6.0 sqlalchemy-2.0.8 sqlparse-0.4.3 typing-extensions-4.5.0

# %% [markdown]
# Load sql

# %%
# %load_ext sql

# %% [markdown]
# Veritabanı Dosyasını Yükleyin

# %%
# %sql sqlite:///chinook.db

# %% [markdown]
# ### SQL Syntax

# %% [markdown]
# Çalma listelerindeki tüm öğeleri ada göre azalan şekilde sıralayın

# %%
# %sql SELECT * FROM playlists ORDER BY Name DESC
# Out:
#  * sqlite:///chinook.db
# Done.
# [(3, 'TV Shows'),
#  (10, 'TV Shows'),
#  (18, 'On-The-Go 1'),
#  (9, 'Music Videos'),
#  (1, 'Music'),
#  (8, 'Music'),
#  (2, 'Movies'),
#  (7, 'Movies'),
#  (17, 'Heavy Metal Classic'),
#  (16, 'Grunge'),
#  (15, 'Classical 101 - The Basics'),
#  (14, 'Classical 101 - Next Steps'),
#  (13, 'Classical 101 - Deep Cuts'),
#  (12, 'Classical'),
#  (11, 'Brazilian Music'),
#  (4, 'Audiobooks'),
#  (6, 'Audiobooks'),
#  (5, '90’s Music')]

# %% [markdown]
# Tüm parça öğelerini listeleyin, ada göre azalan şekilde sıralayın, limit 10

# %%
# %sql SELECT * FROM tracks ORDER BY Name DESC LIMIT 10
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1077, 'Último Pau-De-Arara', 85, 1, 10, 'Corumbá/José Gumarães/Venancio', 200437, 6638563, 0.99),
#  (1073, 'Óia Eu Aqui De Novo', 85, 1, 10, None, 219454, 7469735, 0.99),
#  (2078, 'Óculos', 169, 1, 7, None, 219271, 7262419, 0.99),
#  (3496, 'Étude 1, In C Major - Preludio (Presto) - Liszt', 340, 4, 24, None, 51780, 2229617, 0.99),
#  (333, 'É que Nessa Encarnação Eu Nasci Manga', 29, 1, 9, 'Lucina/Luli', 196519, 6568081, 0.99),
#  (2461, 'É Uma Partida De Futebol', 200, 1, 1, 'Samuel Rosa', 1071, 38747, 0.99),
#  (2817, 'É Preciso Saber Viver', 225, 1, 4, 'Erasmo Carlos/Roberto Carlos', 251115, 8271418, 0.99),
#  (1963, 'É Fogo', 161, 1, 16, 'Mônica Marianno', 194873, 6501520, 0.99),
#  (857, 'Álibi', 69, 1, 7, None, 213237, 6928434, 0.99),
#  (379, 'Água de Beber', 33, 1, 7, 'Antonio Carlos Jobim/Vinicius de Moraes', 146677, 4866476, 0.99)]

# %% [markdown]
# Türe Göre Toplam Albüm Sayısını Listele, toplam sayıya göre sırala

# %%
# %%sql
# SELECT DISTINCT GenreId, COUNT(AlbumId) OVER(PARTITION BY GenreId) AS 'Number of Albums by Genre'
#  FROM tracks
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 1297),
#  (2, 130),
#  (3, 374),
#  (4, 332),
#  (5, 12),
#  (6, 81),
#  (7, 579),
#  (8, 58),
#  (9, 48),
#  (10, 43),
#  (11, 15),
#  (12, 24),
#  (13, 28),
#  (14, 61),
#  (15, 30),
#  (16, 28),
#  (17, 35),
#  (18, 13),
#  (19, 93),
#  (20, 26),
#  (21, 64),
#  (22, 17),
#  (23, 40),
#  (24, 74),
#  (25, 1)]

# %% [markdown]
# ### Birden Fazla Satır ile Sözdizimi Farkı

# %% [markdown]
# Çalışanlar tablosundan Yılları Listele (sqlite için tarih sözdizimi farkı)

# %% [markdown]
# ## SQL Sorgu Sonucunu Python DataFrame'e Dönüştürme

# %%
# %sql SELECT * FROM employees
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'Adams', 'Andrew', 'General Manager', None, '1962-02-18 00:00:00', '2002-08-14 00:00:00', '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com'),
#  (2, 'Edwards', 'Nancy', 'Sales Manager', 1, '1958-12-08 00:00:00', '2002-05-01 00:00:00', '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com'),
#  (3, 'Peacock', 'Jane', 'Sales Support Agent', 2, '1973-08-29 00:00:00', '2002-04-01 00:00:00', '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com'),
#  (4, 'Park', 'Margaret', 'Sales Support Agent', 2, '1947-09-19 00:00:00', '2003-05-03 00:00:00', '683 10 Street SW', 'Calgary', 'AB', 'Canada', 'T2P 5G3', '+1 (403) 263-4423', '+1 (403) 263-4289', 'margaret@chinookcorp.com'),
#  (5, 'Johnson', 'Steve', 'Sales Support Agent', 2, '1965-03-03 00:00:00', '2003-10-17 00:00:00', '7727B 41 Ave', 'Calgary', 'AB', 'Canada', 'T3B 1Y7', '1 (780) 836-9987', '1 (780) 836-9543', 'steve@chinookcorp.com'),
#  (6, 'Mitchell', 'Michael', 'IT Manager', 1, '1973-07-01 00:00:00', '2003-10-17 00:00:00', '5827 Bowness Road NW', 'Calgary', 'AB', 'Canada', 'T3B 0C5', '+1 (403) 246-9887', '+1 (403) 246-9899', 'michael@chinookcorp.com'),
#  (7, 'King', 'Robert', 'IT Staff', 6, '1970-05-29 00:00:00', '2004-01-02 00:00:00', '590 Columbia Boulevard West', 'Lethbridge', 'AB', 'Canada', 'T1K 5N8', '+1 (403) 456-9986', '+1 (403) 456-8485', 'robert@chinookcorp.com'),
#  (8, 'Callahan', 'Laura', 'IT Staff', 6, '1968-01-09 00:00:00', '2004-03-04 00:00:00', '923 7 ST NW', 'Lethbridge', 'AB', 'Canada', 'T1H 1Y8', '+1 (403) 467-3351', '+1 (403) 467-8772', 'laura@chinookcorp.com')]

# %%
result = %sql SELECT * FROM employees
# Out:
#  * sqlite:///chinook.db
# Done.

# %%
type(result)
# Out:
# sql.run.ResultSet

# %%
result_df = result.DataFrame()

# %%
result_df
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00                 7727B 41 Ave
# 5  1973-07-01 00:00:00  2003-10-17 00:00:00         5827 Bowness Road NW
# 6  1970-05-29 00:00:00  2004-01-02 00:00:00  590 Columbia Boulevard West
# 7  1968-01-09 00:00:00  2004-03-04 00:00:00                  923 7 ST NW
#
#          City State Country PostalCode              Phone                Fax  \
# 0    Edmonton    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1     Calgary    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2     Calgary    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3     Calgary    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4     Calgary    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
# 5     Calgary    AB  Canada    T3B 0C5  +1 (403) 246-9887  +1 (403) 246-9899
# 6  Lethbridge    AB  Canada    T1K 5N8  +1 (403) 456-9986  +1 (403) 456-8485
# 7  Lethbridge    AB  Canada    T1H 1Y8  +1 (403) 467-3351  +1 (403) 467-8772
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com
# 5   michael@chinookcorp.com
# 6    robert@chinookcorp.com
# 7     laura@chinookcorp.com

# %%
type(result_df)
# Out:
# pandas.core.frame.DataFrame

# %%
result_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeId  8 non-null      int64
#  1   LastName    8 non-null      object
#  2   FirstName   8 non-null      object
#  3   Title       8 non-null      object
#  4   ReportsTo   7 non-null      float64
#  5   BirthDate   8 non-null      object
#  6   HireDate    8 non-null      object
#  7   Address     8 non-null      object
#  8   City        8 non-null      object
#  9   State       8 non-null      object
#  10  Country     8 non-null      object
#  11  PostalCode  8 non-null      object
#  12  Phone       8 non-null      object
#  13  Fax         8 non-null      object
#  14  Email       8 non-null      object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 1.1+ KB

# %%
result_df.describe
# Out:
# <bound method NDFrame.describe of    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00                 7727B 41 Ave
# 5  1973-07-01 00:00:00  2003-10-17 00:00:00         5827 Bowness Road NW
# 6  1970-05-29 00:00:00  2004-01-02 00:00:00  590 Columbia Boulevard West
# 7  1968-01-09 00:00:00  2004-03-04 00:00:00                  923 7 ST NW
#
#          City State Country PostalCode              Phone                Fax  \
# 0    Edmonton    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1     Calgary    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2     Calgary    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3     Calgary    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4     Calgary    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
# 5     Calgary    AB  Canada    T3B 0C5  +1 (403) 246-9887  +1 (403) 246-9899
# 6  Lethbridge    AB  Canada    T1K 5N8  +1 (403) 456-9986  +1 (403) 456-8485
# 7  Lethbridge    AB  Canada    T1H 1Y8  +1 (403) 467-3351  +1 (403) 467-8772
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com
# 5   michael@chinookcorp.com
# 6    robert@chinookcorp.com
# 7     laura@chinookcorp.com  >

# %% [markdown]
# Başka Bir Örnek

# %%
result1 = %sql SELECT * FROM tracks
# Out:
#  * sqlite:///chinook.db
# Done.

# %%
result1_df = result1.DataFrame()

# %%
result1_df.head()
# Out:
#    TrackId                                     Name  AlbumId  MediaTypeId  \
# 0        1  For Those About To Rock (We Salute You)        1            1
# 1        2                        Balls to the Wall        2            2
# 2        3                          Fast As a Shark        3            2
# 3        4                        Restless and Wild        3            2
# 4        5                     Princess of the Dawn        3            2
#
#    GenreId                                           Composer  Milliseconds  \
# 0        1          Angus Young, Malcolm Young, Brian Johnson        343719
# 1        1                                               None        342562
# 2        1  F. Baltes, S. Kaufman, U. Dirkscneider & W. Ho...        230619
# 3        1  F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. D...        252051
# 4        1                         Deaffy & R.A. Smith-Diesel        375418
#
#       Bytes  UnitPrice
# 0  11170334       0.99
# 1   5510424       0.99
# 2   3990994       0.99
# 3   4331779       0.99
# 4   6290521       0.99

# %%
result1_df['UnitPrice'].mean()
# Out:
# 1.0508050242648312

# %%
result1_df['Milliseconds'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Data Output csv

# %%
result1_df.to_csv('result1.csv')

# %%
result1_df['Bytes'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Toplam Sayı Albümleri Türe ve Tür Adına Göre Listele, toplam sayıya göre sıralayın

# %%
# %%sql
# SELECT G.GenreId, G.Name, COUNT(T.AlbumId) AS 'Number of Albums by Genre' FROM tracks T
#                         JOIN genres G ON T.GenreId=G.GenreId GROUP BY T.GenreId ORDER BY 3 DESC
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'Rock', 1297),
#  (7, 'Latin', 579),
#  (3, 'Metal', 374),
#  (4, 'Alternative & Punk', 332),
#  (2, 'Jazz', 130),
#  (19, 'TV Shows', 93),
#  (6, 'Blues', 81),
#  (24, 'Classical', 74),
#  (21, 'Drama', 64),
#  (14, 'R&B/Soul', 61),
#  (8, 'Reggae', 58),
#  (9, 'Pop', 48),
#  (10, 'Soundtrack', 43),
#  (23, 'Alternative', 40),
#  (17, 'Hip Hop/Rap', 35),
#  (15, 'Electronica/Dance', 30),
#  (13, 'Heavy Metal', 28),
#  (16, 'World', 28),
#  (20, 'Sci Fi & Fantasy', 26),
#  (12, 'Easy Listening', 24),
#  (22, 'Comedy', 17),
#  (11, 'Bossa Nova', 15),
#  (18, 'Science Fiction', 13),
#  (5, 'Rock And Roll', 12),
#  (25, 'Opera', 1)]

# %%
# %%sql
# SELECT * FROM employees LIMIT 1
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'Adams', 'Andrew', 'General Manager', None, '1962-02-18 00:00:00', '2002-08-14 00:00:00', '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com')]

# %%
# %%sql
# SELECT FirstName || ' ' || LastName AS 'Full Name' , strftime('%Y', HireDate) - strftime('%Y', BirthDate) as "Age of Employment" FROM employees
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Andrew Adams', 40),
#  ('Nancy Edwards', 44),
#  ('Jane Peacock', 29),
#  ('Margaret Park', 56),
#  ('Steve Johnson', 38),
#  ('Michael Mitchell', 30),
#  ('Robert King', 34),
#  ('Laura Callahan', 36)]

# %%
# %%sql
# SELECT FirstName || ' ' || LastName AS 'Full Name' , strftime('%Y', HireDate) - strftime('%Y', BirthDate) as "Age of Employment" FROM Employees
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Andrew Adams', 40),
#  ('Nancy Edwards', 44),
#  ('Jane Peacock', 29),
#  ('Margaret Park', 56),
#  ('Steve Johnson', 38),
#  ('Michael Mitchell', 30),
#  ('Robert King', 34),
#  ('Laura Callahan', 36)]

# %%
result = %sql SELECT * FROM employees
# Out:
#  * sqlite:///chinook.db
# Done.

# %%
result_df = result.DataFrame()

# %%
result_df
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# 4  1965-03-03 00:00:00  2003-10-17 00:00:00                 7727B 41 Ave
# 5  1973-07-01 00:00:00  2003-10-17 00:00:00         5827 Bowness Road NW
# 6  1970-05-29 00:00:00  2004-01-02 00:00:00  590 Columbia Boulevard West
# 7  1968-01-09 00:00:00  2004-03-04 00:00:00                  923 7 ST NW
#
#          City State Country PostalCode              Phone                Fax  \
# 0    Edmonton    AB  Canada    T5K 2N1  +1 (780) 428-9482  +1 (780) 428-3457
# 1     Calgary    AB  Canada    T2P 2T3  +1 (403) 262-3443  +1 (403) 262-3322
# 2     Calgary    AB  Canada    T2P 5M5  +1 (403) 262-3443  +1 (403) 262-6712
# 3     Calgary    AB  Canada    T2P 5G3  +1 (403) 263-4423  +1 (403) 263-4289
# 4     Calgary    AB  Canada    T3B 1Y7   1 (780) 836-9987   1 (780) 836-9543
# 5     Calgary    AB  Canada    T3B 0C5  +1 (403) 246-9887  +1 (403) 246-9899
# 6  Lethbridge    AB  Canada    T1K 5N8  +1 (403) 456-9986  +1 (403) 456-8485
# 7  Lethbridge    AB  Canada    T1H 1Y8  +1 (403) 467-3351  +1 (403) 467-8772
#
#                       Email
# 0    andrew@chinookcorp.com
# 1     nancy@chinookcorp.com
# 2      jane@chinookcorp.com
# 3  margaret@chinookcorp.com
# 4     steve@chinookcorp.com
# 5   michael@chinookcorp.com
# 6    robert@chinookcorp.com
# 7     laura@chinookcorp.com

# %%
result1_df['UnitPrice'].value_counts()
# Out:
# 0.99    3290
# 1.99     213
# Name: UnitPrice, dtype: int64

# %% [markdown]
# En yüksek 10 işlem tutarına sahip müşterilerin CustomerID, FirstName, LastName ve Toplam İşlemlerini listeleyin

# %%
# %sql SELECT C.CustomerId,C.FirstName,C.LastName, ROUND(SUM(I.Total),2) AS 'Total Transaction' FROM invoices I JOIN customers C ON I.CustomerId = C.CustomerId GROUP BY C.CustomerId ORDER BY SUM(I.Total) DESC LIMIT 10
# Out:
#  * sqlite:///chinook.db
# Done.
# [(6, 'Helena', 'Holý', 49.62),
#  (26, 'Richard', 'Cunningham', 47.62),
#  (57, 'Luis', 'Rojas', 46.62),
#  (45, 'Ladislav', 'Kovács', 45.62),
#  (46, 'Hugh', "O'Reilly", 45.62),
#  (28, 'Julia', 'Barnett', 43.62),
#  (24, 'Frank', 'Ralston', 43.62),
#  (37, 'Fynn', 'Zimmermann', 43.62),
#  (7, 'Astrid', 'Gruber', 42.62),
#  (25, 'Victor', 'Stevens', 42.62)]

# %%
# %sql SELECT * FROM tracks LIMIT 5
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'For Those About To Rock (We Salute You)', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 343719, 11170334, 0.99),
#  (2, 'Balls to the Wall', 2, 2, 1, None, 342562, 5510424, 0.99),
#  (3, 'Fast As a Shark', 3, 2, 1, 'F. Baltes, S. Kaufman, U. Dirkscneider & W. Hoffman', 230619, 3990994, 0.99),
#  (4, 'Restless and Wild', 3, 2, 1, 'F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman', 252051, 4331779, 0.99),
#  (5, 'Princess of the Dawn', 3, 2, 1, 'Deaffy & R.A. Smith-Diesel', 375418, 6290521, 0.99)]

# %%
# %sql SELECT * FROM invoice_items LIMIT 5
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 1, 2, 0.99, 1),
#  (2, 1, 4, 0.99, 1),
#  (3, 2, 6, 0.99, 1),
#  (4, 2, 8, 0.99, 1),
#  (5, 2, 10, 0.99, 1)]

# %%
# %sql SELECT TrackId, SUM(Quantity) FROM invoice_items GROUP BY TrackId ORDER BY 2 DESC LIMIT 5
# Out:
#  * sqlite:///chinook.db
# Done.
# [(2, 2), (8, 2), (9, 2), (20, 2), (32, 2)]

# %%
# %%sql
# SELECT * FROM albums A JOIN tracks T ON
# A.AlbumId = T.AlbumId  JOIN invoice_items I ON I.TrackId = T.TrackId LIMIT 5
# Out:
#  * sqlite:///chinook.db
# Done.
# [(2, 'Balls to the Wall', 2, 2, 'Balls to the Wall', 2, 2, 1, None, 342562, 5510424, 0.99, 1, 1, 2, 0.99, 1),
#  (3, 'Restless and Wild', 2, 4, 'Restless and Wild', 3, 2, 1, 'F. Baltes, R.A. Smith-Diesel, S. Kaufman, U. Dirkscneider & W. Hoffman', 252051, 4331779, 0.99, 2, 1, 4, 0.99, 1),
#  (1, 'For Those About To Rock We Salute You', 1, 6, 'Put The Finger On You', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 205662, 6713451, 0.99, 3, 2, 6, 0.99, 1),
#  (1, 'For Those About To Rock We Salute You', 1, 8, 'Inject The Venom', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 210834, 6852860, 0.99, 4, 2, 8, 0.99, 1),
#  (1, 'For Those About To Rock We Salute You', 1, 10, 'Evil Walks', 1, 1, 1, 'Angus Young, Malcolm Young, Brian Johnson', 263497, 8611245, 0.99, 5, 2, 10, 0.99, 1)]

# %%
# %%sql
# SELECT A.ArtistId, AR.Name, SUM(I.Quantity) 'Total Invoice' FROM albums A
#         JOIN tracks T ON  A.AlbumId = T.AlbumId
#         JOIN invoice_items I ON I.TrackId = T.TrackId
#         JOIN artists AR ON AR.ArtistID = A.ArtistID
#         GROUP BY A.ArtistId ORDER BY 3 DESC LIMIT 5
# Out:
#  * sqlite:///chinook.db
# Done.
# [(90, 'Iron Maiden', 140),
#  (150, 'U2', 107),
#  (50, 'Metallica', 91),
#  (22, 'Led Zeppelin', 87),
#  (113, 'Os Paralamas Do Sucesso', 45)]

# %%
# %sql SELECT A.ArtistId, AR.Name, SUM(I.Quantity) 'Total Invoice' FROM albums A JOIN tracks T ON A.AlbumId = T.AlbumId JOIN invoice_items I ON I.TrackId = T.TrackId JOIN artists AR ON AR.ArtistID = A.ArtistID GROUP BY A.ArtistId ORDER BY 3 DESC LIMIT 10
# Out:
#  * sqlite:///chinook.db
# Done.
# [(90, 'Iron Maiden', 140),
#  (150, 'U2', 107),
#  (50, 'Metallica', 91),
#  (22, 'Led Zeppelin', 87),
#  (113, 'Os Paralamas Do Sucesso', 45),
#  (58, 'Deep Purple', 44),
#  (82, 'Faith No More', 42),
#  (149, 'Lost', 41),
#  (81, 'Eric Clapton', 40),
#  (124, 'R.E.M.', 39)]

# %%
most_pop = %sql SELECT A.ArtistId, AR.Name, SUM(I.Quantity) 'Total Invoice' FROM albums A JOIN tracks T ON A.AlbumId = T.AlbumId JOIN invoice_items I ON I.TrackId = T.TrackId JOIN artists AR ON AR.ArtistID = A.ArtistID GROUP BY A.ArtistId ORDER BY 3 DESC LIMIT 10
# Out:
#  * sqlite:///chinook.db
# Done.

# %%
most_pop_df = most_pop.DataFrame()

# %%
most_pop_df
# Out:
#    ArtistId                     Name  Total Invoice
# 0        90              Iron Maiden            140
# 1       150                       U2            107
# 2        50                Metallica             91
# 3        22             Led Zeppelin             87
# 4       113  Os Paralamas Do Sucesso             45
# 5        58              Deep Purple             44
# 6        82            Faith No More             42
# 7       149                     Lost             41
# 8        81             Eric Clapton             40
# 9       124                   R.E.M.             39

# %%
most_pop_df.plot(x='Name', y='Total Invoice',figsize=(10,7),ylabel='Number of Sells', xlabel='Artist');
